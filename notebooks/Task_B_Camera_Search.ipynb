# %% [markdown]
# # Task B — Camera Movement Until Circle Visibility
#
# ## Objective
#
# Given an arbitrary crop of the reference image, determine camera movement steps until the reference circle becomes visible.
#
# ## Approach
#
# The crop is treated as a simulated camera viewport. The marker position is detected from the reference image, and directional movement commands are generated until sufficient marker visibility is obtained.
#
# The implementation uses image-space simulation because physical camera calibration parameters were not provided.

# %%
# !python ../src/create_task_b_crops.py
# !python ../src/task_b_search.py
